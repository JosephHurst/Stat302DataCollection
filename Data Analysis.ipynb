# %%
data = read.csv('MoviesData.csv')

# %%
attach(data)

# %%
head(data)
# Out:
#   Movie.Number Movie.Title
# 1  2           The Amazing Spider-Man 2
# 2 11           Se7en
# 3 12           Toy Story
# 4 15           Fight Club
# 5 17           Star Wars: Episode I - The Phantom Menace
# 6 26           Anchorman: The Legend of Ron Burgundy
#   Movie.Url                            Date              Length
# 1 http://www.imdb.com/title/tt1872181/ 2 May 2014        2h 22min
# 2 http://www.imdb.com/title/tt0114369/ 22 September 1995 2h 7min
# 3 http://www.imdb.com/title/tt0114709/ 22 November 1995  1h 21min
# 4 http://www.imdb.com/title/tt0137523/ 15 October 1999   2h 19min
# 5 http://www.imdb.com/title/tt0120915/ 19 May 1999       2h 16min
# 6 http://www.imdb.com/title/tt0357413/ 9 July 2004       1h 34min
#   Genre                                IMDb.Rating Filtered.Genre year
# 1 ['Action', 'Adventure', 'Sci-Fi']    6.7         Sci-Fi/Fantasy 2014
# 2 ['Crime', 'Drama', 'Mystery']        8.6         Crime          1995
# ...

# %%
par(las=2) # make label text perpendicular to axis

# %%
plot(data$Filtered.Genre, horiz = T, las=2, cex.lab = 0.3)
# Out:
# plot without title

# %%
model = lm(IMDb.Rating~Filtered.Genre)

# %%
summary(model)
# Out:
# Call:
# lm(formula = IMDb.Rating ~ Filtered.Genre)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.7281 -0.5776  0.1063  0.7205  3.1417
#
# Coefficients:
#                                      Estimate Std. Error t value Pr(>|t|)
# (Intercept)                          6.080000   0.195610  31.082  < 2e-16 ***
# Filtered.GenreComedy                -0.102441   0.206839  -0.495   0.6205
# Filtered.GenreCrime                  0.413694   0.220464   1.876   0.0609 .
# Filtered.GenreDocumentary/Biography  1.185957   0.224666   5.279 1.62e-07 ***
# Filtered.GenreDrama                  0.897982   0.220894   4.065 5.21e-05 ***
# Filtered.GenreHorror                -0.239649   0.241664  -0.992   0.3216
# Filtered.GenreRomance                0.448125   0.237063   1.890   0.0590 .
# Filtered.GenreRomCom                -0.168095   0.227878  -0.738   0.4609
# Filtered.GenreSci-Fi/Fantasy         0.002353   0.227525   0.010   0.9918
# ...

# %%
confint(model)
# Out:
#                                     2.5 %       97.5 %
# (Intercept)                          5.69611057 6.4638894
# Filtered.GenreComedy                -0.50836844 0.3034865
# Filtered.GenreCrime                 -0.01897375 0.8463611
# Filtered.GenreDocumentary/Biography  0.74504428 1.6268706
# Filtered.GenreDrama                  0.46447047 1.3314928
# Filtered.GenreHorror                -0.71392207 0.2346238
# Filtered.GenreRomance               -0.01711826 0.9133683
# Filtered.GenreRomCom                -0.61531289 0.2791224
# Filtered.GenreSci-Fi/Fantasy        -0.44417189 0.4488778
# Filtered.GenreUndefined             -0.11103159 0.8676983
